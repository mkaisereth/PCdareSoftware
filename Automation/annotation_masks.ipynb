# %%
import json
import ast
import cv2
import numpy as np

f = open("./datasample/original/json/b1.json")

data = json.load(f)

# %%
data

# %%
data["Image Data"][""]["points"]

# %%
pos_list = ast.literal_eval(data["Image Data"][""]["pos"])

# %%
data_list = ast.literal_eval(data["Image Data"][""]["points"])

# %%
print(pos_list)

# %%
image = cv2.imread('./datasample/original/images/train/b1.jpg')

# %%
#first

start_point = data_list[25] 
end_point = data_list[24] 

res = tuple(map(lambda i, j: i + j, start_point, pos_list))
res2 = tuple(map(lambda i, j: i + j, end_point, pos_list))

start_point = tuple(int(x) for x in res)
end_point = tuple(int(x) for x in res2)


start_point2 = data_list[4] 
end_point2 = data_list[5] 

res3 = tuple(map(lambda i, j: i + j, start_point2, pos_list))
res4 = tuple(map(lambda i, j: i + j, end_point2, pos_list))

start_point2 = tuple(int(x) for x in res3)
end_point2 = tuple(int(x) for x in res4)


#second

start_point3 = data_list[27] 
end_point3 = data_list[26] 

res5 = tuple(map(lambda i, j: i + j, start_point3, pos_list))
res6 = tuple(map(lambda i, j: i + j, end_point3, pos_list))

start_point3 = tuple(int(x) for x in res5)
end_point3 = tuple(int(x) for x in res6)

start_point4 = data_list[28] 
end_point4 = data_list[29] 

res7 = tuple(map(lambda i, j: i + j, start_point4, pos_list))
res8 = tuple(map(lambda i, j: i + j, end_point4, pos_list))

start_point4 = tuple(int(x) for x in res7)
end_point4 = tuple(int(x) for x in res8)

#third


start_point5 = data_list[31] 
end_point5 = data_list[30] 

res9 = tuple(map(lambda i, j: i + j, start_point5, pos_list))
res10 = tuple(map(lambda i, j: i + j, end_point5, pos_list))

start_point5 = tuple(int(x) for x in res9)
end_point5 = tuple(int(x) for x in res10)

start_point6 = data_list[32] 
end_point6 = data_list[33] 

res11 = tuple(map(lambda i, j: i + j, start_point6, pos_list))
res12 = tuple(map(lambda i, j: i + j, end_point6, pos_list))

start_point6 = tuple(int(x) for x in res11)
end_point6 = tuple(int(x) for x in res12)

#fourth

start_point7 = data_list[35] 
end_point7 = data_list[34] 

res13 = tuple(map(lambda i, j: i + j, start_point7, pos_list))
res14 = tuple(map(lambda i, j: i + j, end_point7, pos_list))

start_point7 = tuple(int(x) for x in res13)
end_point7 = tuple(int(x) for x in res14)

start_point8 = data_list[36] 
end_point8 = data_list[37] 

res15 = tuple(map(lambda i, j: i + j, start_point8, pos_list))
res16 = tuple(map(lambda i, j: i + j, end_point8, pos_list))

start_point8 = tuple(int(x) for x in res15)
end_point8 = tuple(int(x) for x in res16)

#fifth

start_point9 = data_list[39] 
end_point9 = data_list[38] 

res17 = tuple(map(lambda i, j: i + j, start_point9, pos_list))
res18 = tuple(map(lambda i, j: i + j, end_point9, pos_list))

start_point9 = tuple(int(x) for x in res17)
end_point9 = tuple(int(x) for x in res18)

start_point10 = data_list[40] 
end_point10 = data_list[41] 

res19 = tuple(map(lambda i, j: i + j, start_point10, pos_list))
res20 = tuple(map(lambda i, j: i + j, end_point10, pos_list))

start_point10 = tuple(int(x) for x in res19)
end_point10 = tuple(int(x) for x in res20)

#six

start_point11 = data_list[43] 
end_point11 = data_list[42] 

res21 = tuple(map(lambda i, j: i + j, start_point11, pos_list))
res22 = tuple(map(lambda i, j: i + j, end_point11, pos_list))

start_point11 = tuple(int(x) for x in res21)
end_point11 = tuple(int(x) for x in res22)

start_point12 = data_list[44] 
end_point12 = data_list[45] 

res23 = tuple(map(lambda i, j: i + j, start_point12, pos_list))
res24 = tuple(map(lambda i, j: i + j, end_point12, pos_list))

start_point12 = tuple(int(x) for x in res23)
end_point12 = tuple(int(x) for x in res24)

#seven

start_point13 = data_list[47] 
end_point13 = data_list[46] 

res25 = tuple(map(lambda i, j: i + j, start_point13, pos_list))
res26 = tuple(map(lambda i, j: i + j, end_point13, pos_list))

start_point13 = tuple(int(x) for x in res25)
end_point13 = tuple(int(x) for x in res26)

start_point14 = data_list[48] 
end_point14 = data_list[49] 

res27 = tuple(map(lambda i, j: i + j, start_point14, pos_list))
res28 = tuple(map(lambda i, j: i + j, end_point14, pos_list))

start_point14 = tuple(int(x) for x in res27)
end_point14 = tuple(int(x) for x in res28)

#eight

start_point15 = data_list[51] 
end_point15 = data_list[50] 

res29 = tuple(map(lambda i, j: i + j, start_point15, pos_list))
res30 = tuple(map(lambda i, j: i + j, end_point15, pos_list))

start_point15 = tuple(int(x) for x in res29)
end_point15 = tuple(int(x) for x in res30)

start_point16 = data_list[52] 
end_point16 = data_list[53] 

res31 = tuple(map(lambda i, j: i + j, start_point16, pos_list))
res32 = tuple(map(lambda i, j: i + j, end_point16, pos_list))

start_point16 = tuple(int(x) for x in res31)
end_point16 = tuple(int(x) for x in res32)

#nine

start_point17 = data_list[55] 
end_point17 = data_list[54] 

res33 = tuple(map(lambda i, j: i + j, start_point17, pos_list))
res34 = tuple(map(lambda i, j: i + j, end_point17, pos_list))

start_point17 = tuple(int(x) for x in res33)
end_point17 = tuple(int(x) for x in res34)

start_point18 = data_list[56] 
end_point18 = data_list[57] 

res35 = tuple(map(lambda i, j: i + j, start_point18, pos_list))
res36 = tuple(map(lambda i, j: i + j, end_point18, pos_list))

start_point18 = tuple(int(x) for x in res35)
end_point18 = tuple(int(x) for x in res36)

#ten

start_point19 = data_list[59] 
end_point19 = data_list[58] 

res37 = tuple(map(lambda i, j: i + j, start_point19, pos_list))
res38 = tuple(map(lambda i, j: i + j, end_point19, pos_list))

start_point19 = tuple(int(x) for x in res37)
end_point19 = tuple(int(x) for x in res38)

start_point20 = data_list[60] 
end_point20 = data_list[61] 

res39 = tuple(map(lambda i, j: i + j, start_point20, pos_list))
res40 = tuple(map(lambda i, j: i + j, end_point20, pos_list))

start_point20 = tuple(int(x) for x in res39)
end_point20 = tuple(int(x) for x in res40)

#eleven

start_point21 = data_list[63] 
end_point21 = data_list[62] 

res41 = tuple(map(lambda i, j: i + j, start_point21, pos_list))
res42 = tuple(map(lambda i, j: i + j, end_point21, pos_list))

start_point21 = tuple(int(x) for x in res41)
end_point21 = tuple(int(x) for x in res42)

start_point22 = data_list[64] 
end_point22 = data_list[65] 

res43 = tuple(map(lambda i, j: i + j, start_point22, pos_list))
res44 = tuple(map(lambda i, j: i + j, end_point22, pos_list))

start_point22 = tuple(int(x) for x in res43)
end_point22 = tuple(int(x) for x in res44)

#twelve 

start_point23 = data_list[67] 
end_point23 = data_list[66] 

res45 = tuple(map(lambda i, j: i + j, start_point23, pos_list))
res46 = tuple(map(lambda i, j: i + j, end_point23, pos_list))

start_point23 = tuple(int(x) for x in res45)
end_point23 = tuple(int(x) for x in res46)

start_point24 = data_list[68] 
end_point24 = data_list[69] 

res47 = tuple(map(lambda i, j: i + j, start_point24, pos_list))
res48 = tuple(map(lambda i, j: i + j, end_point24, pos_list))

start_point24 = tuple(int(x) for x in res47)
end_point24 = tuple(int(x) for x in res48)

#thirteenth 

start_point25 = data_list[7] 
end_point25 = data_list[6] 

res49 = tuple(map(lambda i, j: i + j, start_point25, pos_list))
res50 = tuple(map(lambda i, j: i + j, end_point25, pos_list))

start_point25 = tuple(int(x) for x in res49)
end_point25 = tuple(int(x) for x in res50)

start_point26 = data_list[2] 
end_point26 = data_list[3] 

res51 = tuple(map(lambda i, j: i + j, start_point26, pos_list))
res52 = tuple(map(lambda i, j: i + j, end_point26, pos_list))

start_point26 = tuple(int(x) for x in res51)
end_point26 = tuple(int(x) for x in res52)

#fourteenth 

start_point27 = data_list[9] 
end_point27 = data_list[8] 

res53 = tuple(map(lambda i, j: i + j, start_point27, pos_list))
res54 = tuple(map(lambda i, j: i + j, end_point27, pos_list))

start_point27 = tuple(int(x) for x in res53)
end_point27 = tuple(int(x) for x in res54)

start_point28 = data_list[10] 
end_point28 = data_list[11] 

res55 = tuple(map(lambda i, j: i + j, start_point28, pos_list))
res56 = tuple(map(lambda i, j: i + j, end_point28, pos_list))

start_point28 = tuple(int(x) for x in res55)
end_point28 = tuple(int(x) for x in res56)

#fifteenth 

start_point29 = data_list[13] 
end_point29 = data_list[12] 

res57 = tuple(map(lambda i, j: i + j, start_point29, pos_list))
res58 = tuple(map(lambda i, j: i + j, end_point29, pos_list))

start_point29 = tuple(int(x) for x in res57)
end_point29 = tuple(int(x) for x in res58)

start_point30 = data_list[14] 
end_point30 = data_list[15] 

res59 = tuple(map(lambda i, j: i + j, start_point30, pos_list))
res60 = tuple(map(lambda i, j: i + j, end_point30, pos_list))

start_point30 = tuple(int(x) for x in res59)
end_point30 = tuple(int(x) for x in res60)

#sixteenth 
start_point31 = data_list[17] 
end_point31 = data_list[16] 

res61 = tuple(map(lambda i, j: i + j, start_point31, pos_list))
res62 = tuple(map(lambda i, j: i + j, end_point31, pos_list))

start_point31 = tuple(int(x) for x in res61)
end_point31 = tuple(int(x) for x in res62)

start_point32 = data_list[18] 
end_point32 = data_list[19] 

res63 = tuple(map(lambda i, j: i + j, start_point32, pos_list))
res64 = tuple(map(lambda i, j: i + j, end_point32, pos_list))

start_point32 = tuple(int(x) for x in res63)
end_point32 = tuple(int(x) for x in res64)

#seventeenth 
start_point33 = data_list[21] 
end_point33 = data_list[20] 

res65 = tuple(map(lambda i, j: i + j, start_point33, pos_list))
res66 = tuple(map(lambda i, j: i + j, end_point33, pos_list))

start_point33 = tuple(int(x) for x in res65)
end_point33 = tuple(int(x) for x in res66)

start_point34 = data_list[22] 
end_point34 = data_list[23] 

res67 = tuple(map(lambda i, j: i + j, start_point34, pos_list))
res68 = tuple(map(lambda i, j: i + j, end_point34, pos_list))

start_point34 = tuple(int(x) for x in res67)
end_point34 = tuple(int(x) for x in res68)



color = (255, 255, 255) 


blank = np.zeros_like(image, dtype=np.uint8)

# %%
points1 = np.array([start_point, end_point, start_point2, end_point2])
points2 = np.array([start_point3, end_point3, start_point4, end_point4])
points3 = np.array([start_point5, end_point5, start_point6, end_point6])
points4 = np.array([start_point7, end_point7, start_point8, end_point8])
points5 = np.array([start_point9, end_point9, start_point10, end_point10])
points6 = np.array([start_point11, end_point11, start_point12, end_point12])
points7 = np.array([start_point13, end_point13, start_point14, end_point14])
points8 = np.array([start_point15, end_point15, start_point16, end_point16])
points9 = np.array([start_point17, end_point17, start_point18, end_point18])
points10 = np.array([start_point19, end_point19, start_point20, end_point20])
points11 = np.array([start_point21, end_point21, start_point22, end_point22])
points12 = np.array([start_point23, end_point23, start_point24, end_point24])
points13 = np.array([start_point25, end_point25, start_point26, end_point26])
points14 = np.array([start_point27, end_point27, start_point28, end_point28])
points15 = np.array([start_point29, end_point29, start_point30, end_point30])
points16 = np.array([start_point31, end_point31, start_point32, end_point32])
points17 = np.array([start_point33, end_point33, start_point34, end_point34])


cv2.fillConvexPoly(blank, points1, color)
cv2.fillConvexPoly(blank, points2, color)
cv2.fillConvexPoly(blank, points3, color)
cv2.fillConvexPoly(blank, points4, color)
cv2.fillConvexPoly(blank, points5, color)
cv2.fillConvexPoly(blank, points6, color)
cv2.fillConvexPoly(blank, points7, color)
cv2.fillConvexPoly(blank, points8, color)
cv2.fillConvexPoly(blank, points9, color)
cv2.fillConvexPoly(blank, points10, color)
cv2.fillConvexPoly(blank, points11, color)
cv2.fillConvexPoly(blank, points12, color)
cv2.fillConvexPoly(blank, points13, color)
cv2.fillConvexPoly(blank, points14, color)
cv2.fillConvexPoly(blank, points15, color)
cv2.fillConvexPoly(blank, points16, color)
cv2.fillConvexPoly(blank, points17, color)

# %%
cv2.imwrite('./output/b1_label.jpg' , blank)
